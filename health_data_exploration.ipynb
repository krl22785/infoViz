# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

import pandas as pd
import numpy as np
pd.set_option('display.mpl_style', 'default')

import csv

# %% [markdown]
# #### Beneficiary Summary - 3 Files

# %%
ben_2008 = pd.read_csv("DE1_0_2008_Beneficiary_Summary_File_Sample_1.csv", sep = ",")

# %%
ben_2009 = pd.read_csv("DE1_0_2009_Beneficiary_Summary_File_Sample_1.csv", sep = ",")

# %%
ben_2010 = pd.read_csv("DE1_0_2010_Beneficiary_Summary_File_Sample_1.csv", sep = ",")

# %%
ben_2008.ix[:5]
# Out:
#         DESYNPUF_ID  BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# 0  00013D2EFD8E45D1       19230501            NaN                  1
# 1  00016F745862898F       19430101            NaN                  1
# 2  0001FDD721E223DC       19360901            NaN                  2
# 3  00021CA6FF03E670       19410601            NaN                  1
# 4  00024B3D2352D2D0       19360801            NaN                  1
# 5  0002DAE1C81CC70D       19431001            NaN                  1
#
#    BENE_RACE_CD BENE_ESRD_IND  SP_STATE_CODE  BENE_COUNTY_CD  \
# 0             1             0             26             950
# 1             1             0             39             230
# 2             1             0             39             280
# 3             5             0              6             290
# 4             1             0             52             590
# 5             2             0             33             400
#
# ...

# %%
df_ben = pd.concat([ben_2008, ben_2009])

# %%
df_ben = pd.concat([df_ben, ben_2010])

# %%
len(ben_2008) + len(ben_2009) + len(ben_2010)
# Out:
# 343644

# %%
df_ben.head()
# Out:
#         DESYNPUF_ID  BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# 0  00013D2EFD8E45D1       19230501            NaN                  1
# 1  00016F745862898F       19430101            NaN                  1
# 2  0001FDD721E223DC       19360901            NaN                  2
# 3  00021CA6FF03E670       19410601            NaN                  1
# 4  00024B3D2352D2D0       19360801            NaN                  1
#
#    BENE_RACE_CD BENE_ESRD_IND  SP_STATE_CODE  BENE_COUNTY_CD  \
# 0             1             0             26             950
# 1             1             0             39             230
# 2             1             0             39             280
# 3             5             0              6             290
# 4             1             0             52             590
#
#    BENE_HI_CVRAGE_TOT_MONS  BENE_SMI_CVRAGE_TOT_MONS  \
# 0                       12                        12
# 1                       12                        12
# ...

# %% [markdown]
# #### Inpatient

# %%
inp_claims = pd.read_csv("DE1_0_2008_to_2010_Inpatient_Claims_Sample_1.csv", sep = ",")

# %%
inp_claims.head(20)
# Out:
#          DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0   00013D2EFD8E45D1  196661176988405        1     20100312     20100313
# 1   00016F745862898F  196201177000368        1     20090412     20090418
# 2   00016F745862898F  196661177015632        1     20090831     20090902
# 3   00016F745862898F  196091176981058        1     20090917     20090920
# 4   00016F745862898F  196261176983265        1     20100626     20100701
# 5   00052705243EA128  196991176971757        1     20080912     20080912
# 6   0007F12A492FD25D  196661176963773        1     20080919     20080922
# 7   0007F12A492FD25D  196821177025734        1     20100602     20100606
# 8   0007F12A492FD25D  196551177025145        1     20100522     20100612
# 9   0007F12A492FD25D  196831176966961        1     20100616     20100619
# 10  000B97BA2314E971  196231176958277        1     20091209     20091213
# 11  000C7486B11E7030  196641176984178        1     20081015     20081021
# ...

# %% [markdown]
# #### outpatient

# %%
out_claims = pd.read_csv("DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv", sep = ",")
# Out:
# /Library/Python/2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (21,23,24,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
out_claims.head(20)
# Out:
#          DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0   00013D2EFD8E45D1  542192281063886        1     20080904     20080904
# 1   00016F745862898F  542272281166593        1     20090602     20090602
# 2   00016F745862898F  542282281644416        1     20090623     20090623
# 3   0001FDD721E223DC  542642281250669        1     20091011     20091011
# 4   00024B3D2352D2D0  542242281386963        1     20080712     20080712
# 5   00024B3D2352D2D0  542442280980633        1     20090212     20090212
# 6   00024B3D2352D2D0  542422281208985        1     20090627     20090627
# 7   00024B3D2352D2D0  542372281246633        1     20100526     20100526
# 8   0002F28CE057345B  542052281361022        2          NaN          NaN
# 9   0002F28CE057345B  542162280904893        1     20080423     20080423
# 10  0002F28CE057345B  542192281407888        1     20080724     20080724
# 11  0002F28CE057345B  542342281460715        1     20080727     20080727
# ...

# %% [markdown]
# #### Prescription Drug Events

# %%
pres = pd.read_csv("DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_1.csv", sep = ",")
# Out:
# /Library/Python/2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
pres.head(10)
# Out:
#         DESYNPUF_ID           PDE_ID   SRVC_DT PROD_SRVC_ID  QTY_DSPNSD_NUM  \
# 0  00013D2EFD8E45D1  233664490397622  20080103    247037252              30
# 1  00013D2EFD8E45D1  233644490171972  20080105    223039502              10
# 2  00013D2EFD8E45D1  233974489116848  20080109    364724812             120
# 3  00013D2EFD8E45D1  233574491083209  20080123    179180672              30
# 4  00013D2EFD8E45D1  233024491180571  20080124  58016005300              30
# 5  00013D2EFD8E45D1  233884492803278  20080124  53650001801              30
# 6  00013D2EFD8E45D1  233594491623171  20080125      8032506             180
# 7  00013D2EFD8E45D1  233894491962732  20080129  58016081825             100
# 8  00013D2EFD8E45D1  233344491666810  20080201  51129143701              30
# 9  00013D2EFD8E45D1  233884490733605  20080205  67668013231              10
#
#    DAYS_SUPLY_NUM  PTNT_PAY_AMT  TOT_RX_CST_AMT
# 0              20            10             120
# ...

# %% [markdown]
# #### Exploration

# %%
col_diag = ['SP_ALZHDMTA', 'SP_CHF', 'SP_CHRNKIDN', 'SP_CNCR', \
            'SP_COPD', 'SP_DEPRESSN', 'SP_DIABETES', 'SP_ISCHMCHT', \
            'SP_OSTEOPRS', 'SP_RA_OA', 'SP_STRKETIA']


df_ben_grouped = df_ben.groupby(['DESYNPUF_ID', 'BENE_BIRTH_DT', 'BENE_DEATH_DT', \
                                 'BENE_SEX_IDENT_CD', 'BENE_RACE_CD'])[col_diag]

# %%
df_ben_summary = df_ben_grouped.agg('median')
df_ben_summary.reset_index(inplace=True)

# %%
df_ben_summary.head()
# Out:
#         DESYNPUF_ID  BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# 0  0007E57CC13CE880       19340101       20101201                  1
# 1  0010D6F80D245D62       19391201       20090701                  2
# 2  0021940CF994C374       19360101       20090101                  1
# 3  0033C90574583C0D       19360801       20080901                  2
# 4  00521D781532612C       19370801       20080701                  2
#
#    BENE_RACE_CD  SP_ALZHDMTA  SP_CHF  SP_CHRNKIDN  SP_CNCR  SP_COPD  \
# 0             1            2       2            2        2        2
# 1             1            2       2            2        2        2
# 2             1            2       2            2        2        2
# 3             1            2       2            2        2        2
# 4             1            1       2            2        2        2
#
#    SP_DEPRESSN  SP_DIABETES  SP_ISCHMCHT  SP_OSTEOPRS  SP_RA_OA  SP_STRKETIA
# ...

# %%
test = pd.merge(out_claims[['DESYNPUF_ID', 'CLM_PMT_AMT']], df_ben_summary, on = 'DESYNPUF_ID', how = 'left')
test.fillna(0, inplace=True)

# %%
test['ICD9_DGNS_CD_1'][test['ICD9_DGNS_CD_1'] != 0] = 1 
test['ICD9_DGNS_CD_2'][test['ICD9_DGNS_CD_2'] != 0] = 1 
test['ICD9_DGNS_CD_3'][test['ICD9_DGNS_CD_3'] != 0] = 1 
test['ICD9_DGNS_CD_4'][test['ICD9_DGNS_CD_4'] != 0] = 1 
test['ICD9_DGNS_CD_5'][test['ICD9_DGNS_CD_5'] != 0] = 1 
test['ICD9_DGNS_CD_6'][test['ICD9_DGNS_CD_6'] != 0] = 1 
test['ICD9_DGNS_CD_7'][test['ICD9_DGNS_CD_7'] != 0] = 1 
test['ICD9_DGNS_CD_8'][test['ICD9_DGNS_CD_8'] != 0] = 1
test['ICD9_DGNS_CD_9'][test['ICD9_DGNS_CD_9'] != 0] = 1
test['ICD9_DGNS_CD_10'][test['ICD9_DGNS_CD_10'] != 0] = 1

test['ICD9_PRCDR_CD_1'][test['ICD9_PRCDR_CD_1'] != 0] = 1
test['ICD9_PRCDR_CD_2'][test['ICD9_PRCDR_CD_2'] != 0] = 1
test['ICD9_PRCDR_CD_3'][test['ICD9_PRCDR_CD_3'] != 0] = 1
test['ICD9_PRCDR_CD_4'][test['ICD9_PRCDR_CD_4'] != 0] = 1
test['ICD9_PRCDR_CD_5'][test['ICD9_PRCDR_CD_5'] != 0] = 1
test['ICD9_PRCDR_CD_6'][test['ICD9_PRCDR_CD_6'] != 0] = 1

# %%
#test.iloc[:,31:76].columns
service_list = ['HCPCS_CD_1', 'HCPCS_CD_2',u'HCPCS_CD_3', u'HCPCS_CD_3', u'HCPCS_CD_4', u'HCPCS_CD_5', \
      u'HCPCS_CD_6', u'HCPCS_CD_7', u'HCPCS_CD_8', u'HCPCS_CD_9', u'HCPCS_CD_10', u'HCPCS_CD_11', \
      u'HCPCS_CD_12', u'HCPCS_CD_13', u'HCPCS_CD_14', u'HCPCS_CD_15', u'HCPCS_CD_16', u'HCPCS_CD_17', \
      u'HCPCS_CD_18', u'HCPCS_CD_19', u'HCPCS_CD_20', u'HCPCS_CD_21', u'HCPCS_CD_22', u'HCPCS_CD_23', \
      u'HCPCS_CD_24', u'HCPCS_CD_25', u'HCPCS_CD_26', u'HCPCS_CD_27', u'HCPCS_CD_28', u'HCPCS_CD_29', \
      u'HCPCS_CD_30', u'HCPCS_CD_31', u'HCPCS_CD_32', u'HCPCS_CD_33', u'HCPCS_CD_34', u'HCPCS_CD_35', \
      u'HCPCS_CD_36', u'HCPCS_CD_37', u'HCPCS_CD_38', u'HCPCS_CD_39', u'HCPCS_CD_40', u'HCPCS_CD_41', \
      u'HCPCS_CD_42', u'HCPCS_CD_43', u'HCPCS_CD_44', u'HCPCS_CD_45']

# %%
test['sum_services'] = test[service_list].sum(axis=1)

# %%
test.iloc[:,6:].columns
# Out:
# Index([u'SP_ALZHDMTA', u'SP_CHF', u'SP_CHRNKIDN', u'SP_CNCR', u'SP_COPD', u'SP_DEPRESSN', u'SP_DIABETES', u'SP_ISCHMCHT', u'SP_OSTEOPRS', u'SP_RA_OA', u'SP_STRKETIA'], dtype='object')

# %%
test['total_CC'] = test[col_diag].sum(axis=1)

# %%
test[test['DESYNPUF_ID'] == '0021940CF994C374']
# Out:
#         DESYNPUF_ID  BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# 0  0021940CF994C374       19360101       20090101                  1
# 1  0021940CF994C374       19360101       20090101                  1
# 2  0021940CF994C374       19360101       20090101                  1
# 3  0021940CF994C374       19360101       20090101                  1
# 4  0021940CF994C374       19360101       20090101                  1
#
#    BENE_RACE_CD  SP_ALZHDMTA  SP_CHF  SP_CHRNKIDN  SP_CNCR  SP_COPD  \
# 0             1            2       2            2        2        2
# 1             1            2       2            2        2        2
# 2             1            2       2            2        2        2
# 3             1            2       2            2        2        2
# 4             1            2       2            2        2        2
#
#    SP_DEPRESSN  SP_DIABETES  SP_ISCHMCHT  SP_OSTEOPRS  SP_RA_OA  SP_STRKETIA  \
# ...

# %%
test = pd.merge(df_ben_summary, out_claims[['DESYNPUF_ID', 'CLM_PMT_AMT']], on = 'DESYNPUF_ID')

# %%
test['SP_ALZHDMTA'][test['SP_ALZHDMTA'] == 2] = 0 
test['SP_CHF'][test['SP_CHF'] == 2] = 0 
test['SP_CHRNKIDN'][test['SP_CHRNKIDN'] == 2] = 0 
test['SP_CNCR'][test['SP_CNCR'] == 2] = 0   
test['SP_COPD'][test['SP_COPD'] == 2] = 0
test['SP_DEPRESSN'][test['SP_DEPRESSN'] == 2] = 0
test['SP_DIABETES'][test['SP_DIABETES']  == 2] = 0 
test['SP_ISCHMCHT'][test['SP_ISCHMCHT'] == 2] = 0  
test['SP_OSTEOPRS'][test['SP_OSTEOPRS'] == 2] = 0  
test['SP_RA_OA'][test['SP_RA_OA'] == 2] = 0  
test['SP_STRKETIA'][test['SP_STRKETIA'] == 2] = 0

# %%
#0021940CF994C374

test['total_CC'] = test[col_diag].sum(axis=1)

# %%
test_gb = test.groupby(['DESYNPUF_ID', 'total_CC'])['CLM_PMT_AMT']

# %%
test1 = pd.DataFrame(test_gb.agg('mean'))
test1.reset_index(inplace=True )

# %%
test1
# Out:
#          DESYNPUF_ID  total_CC  CLM_PMT_AMT
# 0   0021940CF994C374         2    50.000000
# 1   00521D781532612C         5   176.666667
# 2   0060C263DA4EBBAF         8   320.555556
# 3   0061141AB18FFA96         8    65.000000
# 4   00A0D9D42D1EDE2C         3   181.666667
# 5   00C9FEFBD0270240         1   200.000000
# 6   00E3731EF0CD4C2A         1   161.666667
# 7   00F0CF06C19E4E46         1   143.333333
# 8   0128FB0FDF6CA432         3   257.333333
# 9   012C063F786472CB         1    86.666667
# 10  0137FCCF3F535BB0         0   895.000000
# 11  013C8094EEB51A84         6   520.000000
# 12  013FD49E86CC2913         2    30.000000
# 13  01516C05C0E6C5B7         4   255.000000
# 14  0152D6726F90EFCF         2    95.000000
# 15  016A1C0A1C41D1CC         2    93.333333
# 16  01CC860BCCB9EAF9         0    43.333333
# 17  01DE73287BF13759         6   141.666667
# 18  01FD0B6A08303181         1   560.000000
# 19  020A9E5704E37CC3         1    75.000000
# ...

# %%
# final = test[['total_CC', 'CLM_PMT_AMT']]
test1.boxplot(by = 'total_CC', figsize = (12,8))

# %%
plt.scatter(np.random.normal(test1['total_CC'], .04), test1['CLM_PMT_AMT'], alpha = .2, c = 'r')
#final.boxplot(by = 'total_CC')

# %%
np.random.normal(1, .02)
# Out:
# 0.983986886758877

# %%
np.random.normal(2, 0.04)
# Out:
# 1.967780703110907

# %%
# Out:
# array([ 2.02083042,  1.96789448,  2.05282287, ...,  2.02543882,
#         1.97112027,  2.03605651])
